# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from time import sleep
import pandas as pd

# %%
def obter_driver():
    return webdriver.Chrome()

def abrir_pagina(driver):
    driver.get("https://www.cnnbrasil.com.br/internacional/veja-o-ranking-completo-de-todos-os-paises-por-idh/")

# %%
driver= obter_driver()
abrir_pagina(driver)

# %%
cookies= driver.find_element_by_xpath("""//*[@id="pop__gdpr"]/div[1]""")
cookies.click()

# %%
iframe = driver.find_element_by_xpath("""/html/body/div[2]/div/div/main/article/div/div[4]/iframe""")
driver.switch_to.frame(iframe)

# %%
def prox_pag():
    p = driver.find_element_by_xpath("""//*[@id="pagination"]/button[2]""")
    p.click()

# %%
linhas = []
for r in range(0,12):
    #try:
        table_inner = driver.find_element_by_id("table-inner")
        while(teste:=table_inner.find_elements_by_tag_name('body-row')):
            print(teste.text)
        conteudo = table_inner.text.split()
        for x in range(0,len(conteudo)-2,3):
            tmp = []
            tmp.append(conteudo[x])
            tmp.append(conteudo[x+1])
            tmp.append(conteudo[x+2])
            linhas.append(tmp)
        prox_pag()
        sleep(1)
    #except Exception as erro:
        #continue
df_idh = pd.DataFrame(linhas)

# %%
df_idh.head(50)
# Out:
#      0   1   2
# 0    C   o   l
# 1    o   c   a
# 2    ç   ã   o
# 3   \n   P   a
# 4    í   s  \n
# 5    I   D   H
# 6   \n   1  \n
# 7    N   o   r
# 8    u   e   g
# 9    a  \n   0
# 10   ,   9   5
# 11   7  \n   2
# 12  \n   S   u
# 13   í   ç   a
# 14  \n   0   ,
# 15   9   5   5
# 16  \n   2  \n
# 17   I   r   l
# 18   a   n   d
# 19   a  \n   0
# 20   ,   9   5
# 21   5  \n   4
# 22  \n   H   o
# 23   n   g
# 24   K   o   n
# 25   g       (
# 26   C   h   i
# 27   n   a   )
# 28  \n   0   ,
# 29   9   4   9
# 30  \n   4  \n
# 31   I   s   l
# 32   â   n   d
# 33   i   a  \n
# 34   0   ,   9
# 35   4   9  \n
# 36   6  \n   A
# 37   l   e   m
# 38   a   n   h
# 39   a  \n   0
# 40   ,   9   4
# 41   7  \n   7
# 42  \n   S   u
# 43   é   c   i
# 44   a  \n   0
# 45   ,   9   4
# 46   5  \n   8
# 47  \n   A   u
# 48   s   t   r
# 49   á   l   i

# %%
df_idh.to_csv('./Data/teste_idh_2019.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-7a147747021f> in <module>
# ----> 1 df_idh.to_csv('./Data/teste_idh_2019.csv')
#
# AttributeError: 'list' object has no attribute 'to_csv'

# %%
df_idh = df_idh.str.replace("\n", "','")
df_idh
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-416672d4770b> in <module>
# ----> 1 df_idh = df_idh.str.replace("\n", "','")
#       2 df_idh
#
# AttributeError: 'list' object has no attribute 'str'

# %%
ranking = []
pais = []
idh = []

for n in range(0, (len(df_idh)), 3):
    ranking.append(df_idh[n])
    idh.append(df_idh[n+2])
    pais.append(df_idh[n+1])
    
print(ranking, pais, idh)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-ca6a09a9102e> in <module>
#       5 for n in range(0, 180, 3):
#       6     ranking.append(df_idh[n])
# ----> 7     idh.append(df_idh[n+2])
#       8     pais.append(df_idh[n+1])
#       9
#
# IndexError: list index out of range
