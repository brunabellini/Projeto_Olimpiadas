# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from time import sleep
import numpy as np
import pandas as pd

# %%
def obter_driver():
    return webdriver.Chrome()

def abrir_pagina(driver):
    driver.get("http://www.olympedia.org/statistics/medal/athlete")

# %%
driver = obter_driver()
abrir_pagina(driver)

# %%
medals_by_athlete = driver.find_element_by_xpath("""//*[@id="country_select"]""")
medals_by_athlete.click()

# %%
country = driver.find_element_by_xpath("""//*[@id="country_select"]/option[32]""")
country.click()

# %%
top = driver.find_element_by_xpath("""//*[@id="filter"]/select[10]""")
top.click()

# %%
top_all = driver.find_element_by_xpath("""//*[@id="filter"]/select[10]/option[3]""")
top_all.click()

# %%
txt_table = []
head = driver.find_elements_by_tag_name('th')

for title in head:
    title = title.text
    txt_table.append(title)
    
lines = driver.find_elements_by_tag_name('td')

for content in lines:
    content = content.text
    txt_table.append(content)

txt_table
# Out:
# ['Athlete',
#  'Nat',
#  'Gold',
#  'Silver',
#  'Bronze',
#  'Total',
#  'Robert Scheidt',
#  'BRA',
#  '2',
#  '2',
#  '1',
#  '5',
#  'Serginho',
#  'BRA',
#  '2',
#  '2',
#  '0',
#  '4',
#  'Torben Grael',
#  'BRA',
#  '2',
#  '1',
#  '2',
#  '5',
#  'Marcelo Ferreira',
#  'BRA',
#  '2',
#  '0',
#  '1',
#  '3',
#  'Giovane',
#  'BRA',
#  '2',
#  '0',
#  '0',
#  '2',
#  'Maurício',
#  'BRA',
#  '2',
#  '0',
#  '0',
#  '2',
#  'Adhemar da Silva',
#  'BRA',
#  '2',
#  '0',
#  '0',
#  '2',
#  'Fabiana',
#  'BRA',
#  '2',
#  '0',
#  '0',
#  '2',
#  'Paula',
#  'BRA',
#  '2',
#  '0',
#  '0',
#  '2',
#  'Thaísa',
#  'BRA',
#  '2',
#  '0',
#  '0',
#  '2',
#  'Jaque',
#  'BRA',
#  '2',
#  '0',
#  '0',
#  '2',
#  'Sheilla',
#  'BRA',
#  '2',
#  '0',
#  '0',
#  '2',
#  'Fabi',
#  'BRA',
#  '2',
#  '0',
#  '0',
#  '2',
#  'Kahena Kunze',
#  'BRA',
#  '2',
#  '0',
#  '0',
#  '2',
#  'Martine Grael',
#  'BRA',
#  '2',
#  '0',
#  '0',
#  '2',
#  'Caio César dos Santos',
#  'BRA',
#  '2',
# ...

# %%
atleta = []
noccode = []
ouro = []
prata = []
bronze = []
total= []

for n in range(0, (len(txt_table)), 6):
    atleta.append(txt_table[n])
    noccode.append(txt_table[n+1])
    ouro.append(txt_table[n+2])
    prata.append(txt_table[n+3])
    bronze.append(txt_table[n+4])
    total.append(txt_table[n+5])
    
print(atleta, noccode,ouro,prata, bronze, total)
# Out:
# ['Athlete', 'Robert Scheidt', 'Serginho', 'Torben Grael', 'Marcelo Ferreira', 'Giovane', 'Maurício', 'Adhemar da Silva', 'Fabiana', 'Paula', 'Thaísa', 'Jaque', 'Sheilla', 'Fabi', 'Kahena Kunze', 'Martine Grael', 'Caio César dos Santos', 'Isaquias Queiroz', 'Dante', 'Giba', 'Rodrigão', 'Bruninho', 'Flávia Saraiva', 'Matheus Santana', 'Emanuel', 'Ricardo', 'Thiago Braz', 'Amauri', 'Joaquim Cruz', 'Gustavo', 'André Heller', 'Ricardinho', 'André Nascimento', 'Anderson', 'Arthur Zanetti', 'Fê Garay', 'Natália', 'Tandara', 'Alison', 'Neymar', 'Lucão', 'Wallace', 'Rebeca Andrade', 'Layana Colman', 'Orlando Luz', 'Rodrigo Pessoa', 'Fofão', 'César Cielo Filho', 'Aurélio Miguel', 'Guilherme Paraense', 'Sandra', 'Walewska', 'Rogério Sampaio', 'Jackie Silva', 'Nalbert', 'Jorge Edson', 'Janelson', 'Douglas', 'Paulão', 'Pampa', 'Carlão', 'Marcelo Negrão', 'Talmo', 'Tande', 'Lars Bjorkstrom', 'Eduardo Penido', 'Marcos Soares', 'Alex Welter', 'Maurren Maggi', 'Sassá', 'Valeskinha', 'Mari', 'Sarah Me
# ...

# %%
atleta = atleta[1:]
noccode = noccode[1:]
ouro = ouro[1:]
prata = prata[1:]
bronze = bronze[1:]
total = total[1:]

# %%
df_atletas = pd.DataFrame({'Athlete': atleta, 'Nat': noccode, 'Gold': ouro, 'Silver':prata, 'Bronze':bronze, 'Total':total})
df_atletas = df_atletas.rename(columns={'Athlete': 'Nome do atleta', 'Nat':'Nacionalidade','Gold': 'Ouro', 'Silver':'Prata','Total': 'Total medalhas'})

df_atletas
# Out:
#            Nome do atleta Nacionalidade Ouro Prata Bronze Total medalhas
# 0          Robert Scheidt           BRA    2     2      1              5
# 1                Serginho           BRA    2     2      0              4
# 2            Torben Grael           BRA    2     1      2              5
# 3        Marcelo Ferreira           BRA    2     0      1              3
# 4                 Giovane           BRA    2     0      0              2
# ..                    ...           ...  ...   ...    ...            ...
# 465  Gilbert Klier Junior           BRA    0     0      1              1
# 466          Letícia Lima           BRA    0     0      1              1
# 467        Jaqueline Lima           BRA    0     0      1              1
# 468          Eduarda Rosa           BRA    0     0      1              1
# 469          Sandy Macedo           BRA    0     0      1              1
#
# [470 rows x 6 columns]
